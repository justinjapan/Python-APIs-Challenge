# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
settings = {"units": "imperial", "appid": weather_api_key}

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url = f"{url}appid=1b530a1e3a52174247075e2463f00399&units={units}&q={city}"
g_url = "http://api.openweathermap.org/data/2.5/weather?appid=1b530a1e3a52174247075e2463f00399&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(g_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | bintulu
# Processing Record 3 of Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | chapais
# City not found. Skipping...
# Processing Record 8 of Set 1 | nesterov
# Processing Record 9 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | vostok
# City not found. Skipping...
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | vaitape
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | charlottetown
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | portland
# Processing Record 18 of Set 1 | xuddur
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | narsaq
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 26 of Set 1 | tigre
# Processing Record 27 of Set 1 | gusau
# Processing Record 28 of Set 1 | playa del carmen
# Processing Record 29 of Set 1 | birin
# Processing Record 30 of Set 1 | kloulklubed
# Processing Record 31 of Set 1 | aklavik
# Processing Record 32 of Set 1 | kalmunai
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 36 of Set 1 | puerto madero
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | moree
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | xiaoweizhai
# Processing Record 43 of Set 1 | samarinda
# Processing Record 44 of Set 1 | mount gambier
# Processing Record 45 of Set 1 | susehri
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | caravelas
# Processing Record 49 of Set 1 | sambava
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | castro
# City not found. Skipping...
# Processing Record 3 of Set 2 | nantucket
# Processing Record 4 of Set 2 | sawtell
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | sola
# Processing Record 7 of Set 2 | mehamn
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | dukat
# Processing Record 14 of Set 2 | nemuro
# Processing Record 15 of Set 2 | antalaha
# Processing Record 16 of Set 2 | kafanchan
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | meulaboh
# Processing Record 20 of Set 2 | grand gaube
# Processing Record 21 of Set 2 | yagodnoye
# Processing Record 22 of Set 2 | bahia honda
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | namibe
# Processing Record 25 of Set 2 | tayu
# Processing Record 26 of Set 2 | carupano
# Processing Record 27 of Set 2 | roebourne
# Processing Record 28 of Set 2 | broome
# City not found. Skipping...
# Processing Record 29 of Set 2 | maldonado
# Processing Record 30 of Set 2 | saint-pierre
# Processing Record 31 of Set 2 | ugoofaaru
# Processing Record 32 of Set 2 | half moon bay
# Processing Record 33 of Set 2 | boyolangu
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | buala
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | cockburn town
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | vilhena
# Processing Record 42 of Set 2 | opunake
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | ouallam
# Processing Record 45 of Set 2 | dodoma
# Processing Record 46 of Set 2 | tsuruoka
# Processing Record 47 of Set 2 | iskateley
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | dikson
# City not found. Skipping...
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | olenino
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | taoudenni
# City not found. Skipping...
# Processing Record 5 of Set 3 | port blair
# Processing Record 6 of Set 3 | ulvik
# Processing Record 7 of Set 3 | mys shmidta
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | padang
# Processing Record 11 of Set 3 | paranaiba
# City not found. Skipping...
# Processing Record 12 of Set 3 | weymouth
# City not found. Skipping...
# Processing Record 13 of Set 3 | omsukchan
# Processing Record 14 of Set 3 | porto novo
# Processing Record 15 of Set 3 | khasan
# Processing Record 16 of Set 3 | maragogi
# Processing Record 17 of Set 3 | acapulco
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | letlhakane
# Processing Record 20 of Set 3 | ismailia
# Processing Record 21 of Set 3 | araouane
# Processing Record 22 of Set 3 | tezu
# Processing Record 23 of Set 3 | naliya
# Processing Record 24 of Set 3 | hazorasp
# Processing Record 25 of Set 3 | pangody
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | tabou
# Processing Record 28 of Set 3 | avarua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 3 | tarko-sale
# Processing Record 30 of Set 3 | tadine
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | ahuimanu
# Processing Record 33 of Set 3 | laguna
# Processing Record 34 of Set 3 | sur
# Processing Record 35 of Set 3 | najran
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | lianran
# Processing Record 38 of Set 3 | komsomolskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | wajima
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | bluff
# City not found. Skipping...
# Processing Record 42 of Set 3 | gabu
# Processing Record 43 of Set 3 | coihaique
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | necochea
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | mana
# City not found. Skipping...
# Processing Record 48 of Set 3 | puertollano
# Processing Record 49 of Set 3 | loandjili
# Processing Record 1 of Set 4 | vitoria de santo antao
# Processing Record 2 of Set 4 | darhan
# Processing Record 3 of Set 4 | mahajanga
# Processing Record 4 of Set 4 | kirakira
# Processing Record 5 of Set 4 | minab
# Processing Record 6 of Set 4 | simdega
# Processing Record 7 of Set 4 | cherskiy
# Processing Record 8 of Set 4 | bucerias
# Processing Record 9 of Set 4 | narsimhapur
# City not found. Skipping...
# Processing Record 10 of Set 4 | qixingtai
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | bardiyah
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | san vicente
# Processing Record 15 of Set 4 | puerto ayora
# Processing Record 16 of Set 4 | berlevag
# Processing Record 17 of Set 4 | fort nelson
# Processing Record 18 of Set 4 | mount isa
# City not found. Skipping...
# Processing Record 19 of Set 4 | tolstoy-yurt
# Processing Record 20 of Set 4 | port arthur
# Processing Record 21 of Set 4 | nelson bay
# Processing Record 22 of Set 4 | yar-sale
# Processing Record 23 of Set 4 | luwingu
# Processing Record 24 of Set 4 | sayyan
# Processing Record 25 of Set 4 | lingao
# Processing Record 26 of Set 4 | arlit
# Processing Record 27 of Set 4 | nanortalik
# Processing Record 28 of Set 4 | salisbury
# Processing Record 29 of Set 4 | colares
# Processing Record 30 of Set 4 | auki
# Processing Record 31 of Set 4 | netivot
# Processing Record 32 of Set 4 | fairbanks
# Processing Record 33 of Set 4 | butaritari
# Processing Record 34 of Set 4 | port hardy
# Processing Record 35 of Set 4 | gorey
# Processing Record 36 of Set 4 | kudahuvadhoo
# Processing Record 37 of Set 4 | leningradskiy
# Processing Record 38 of Set 4 | kaeo
# Processing Record 39 of Set 4 | mannarakkat
# Processing Record 40 of Set 4 | husavik
# Processing Record 41 of Set 4 | sakakah
# Processing Record 42 of Set 4 | mount pleasant
# Processing Record 43 of Set 4 | yucca valley
# City not found. Skipping...
# Processing Record 44 of Set 4 | netrakona
# Processing Record 45 of Set 4 | tucurui
# Processing Record 46 of Set 4 | wanning
# Processing Record 47 of Set 4 | port hedland
# Processing Record 48 of Set 4 | jinchang
# City not found. Skipping...
# Processing Record 49 of Set 4 | magistralnyy
# City not found. Skipping...
# Processing Record 1 of Set 5 | navahrudak
# Processing Record 2 of Set 5 | belaya gora
# Processing Record 3 of Set 5 | college
# Processing Record 4 of Set 5 | tecozautla
# Processing Record 5 of Set 5 | madison
# Processing Record 6 of Set 5 | sirnak
# Processing Record 7 of Set 5 | provideniya
# Processing Record 8 of Set 5 | rio gallegos
# Processing Record 9 of Set 5 | muros
# Processing Record 10 of Set 5 | yining
# Processing Record 11 of Set 5 | gigmoto
# Processing Record 12 of Set 5 | sapa
# Processing Record 13 of Set 5 | mogadishu
# Processing Record 14 of Set 5 | bonthe
# Processing Record 15 of Set 5 | sheopur
# Processing Record 16 of Set 5 | wairoa
# Processing Record 17 of Set 5 | saint-georges
# Processing Record 18 of Set 5 | elizabeth city
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | prince rupert
# Processing Record 21 of Set 5 | muisne
# City not found. Skipping...
# Processing Record 22 of Set 5 | hammerfest
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | east london
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | belmonte
# Processing Record 28 of Set 5 | poole
# City not found. Skipping...
# Processing Record 29 of Set 5 | clifton springs
# City not found. Skipping...
# Processing Record 30 of Set 5 | valuyki
# Processing Record 31 of Set 5 | qandala
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | east millcreek
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | goderich
# Processing Record 36 of Set 5 | grajau
# Processing Record 37 of Set 5 | iquique
# City not found. Skipping...
# Processing Record 38 of Set 5 | asyut
# Processing Record 39 of Set 5 | san carlos de bariloche
# Processing Record 40 of Set 5 | arica
# Processing Record 41 of Set 5 | gushi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 5 | olafsvik
# Processing Record 43 of Set 5 | apiai
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | gatesville
# Processing Record 47 of Set 5 | luderitz
# Processing Record 48 of Set 5 | salalah
# Processing Record 49 of Set 5 | camacha
# Processing Record 1 of Set 6 | milove
# Processing Record 2 of Set 6 | shelburne
# Processing Record 3 of Set 6 | pasighat
# Processing Record 4 of Set 6 | kyshtovka
# Processing Record 5 of Set 6 | murashi
# Processing Record 6 of Set 6 | sitka
# Processing Record 7 of Set 6 | ravar
# Processing Record 8 of Set 6 | rabat
# Processing Record 9 of Set 6 | nara
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | antofagasta
# Processing Record 13 of Set 6 | brae
# Processing Record 14 of Set 6 | chuy
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | tura
# Processing Record 17 of Set 6 | vorozhba
# Processing Record 18 of Set 6 | marzuq
# Processing Record 19 of Set 6 | bend
# Processing Record 20 of Set 6 | ambulu
# Processing Record 21 of Set 6 | lalsk
# Processing Record 22 of Set 6 | seabra
# Processing Record 23 of Set 6 | lavrentiya
# Processing Record 24 of Set 6 | casablanca
# Processing Record 25 of Set 6 | baykit
# Processing Record 26 of Set 6 | lata
# Processing Record 27 of Set 6 | hattiesburg
# Processing Record 28 of Set 6 | villa carlos paz
# Processing Record 29 of Set 6 | starominskaya
# Processing Record 30 of Set 6 | naushki
# Processing Record 31 of Set 6 | oranjemund
# Processing Record 32 of Set 6 | ponta do sol
# Processing Record 33 of Set 6 | mantua
# Processing Record 34 of Set 6 | carballo
# Processing Record 35 of Set 6 | mozarlandia
# City not found. Skipping...
# Processing Record 36 of Set 6 | tubmanburg
# Processing Record 37 of Set 6 | tautira
# Processing Record 38 of Set 6 | moose factory
# Processing Record 39 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 6 | hlotse
# Processing Record 41 of Set 6 | guozhen
# Processing Record 42 of Set 6 | bushehr
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | ohara
# Processing Record 45 of Set 6 | turukhansk
# Processing Record 46 of Set 6 | maracaju
# Processing Record 47 of Set 6 | barcelos
# Processing Record 48 of Set 6 | maarianhamina
# Processing Record 49 of Set 6 | carnarvon
# Processing Record 1 of Set 7 | bousse
# Processing Record 2 of Set 7 | tenali
# Processing Record 3 of Set 7 | harper
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | loreto
# City not found. Skipping...
# Processing Record 6 of Set 7 | san juan del sur
# Processing Record 7 of Set 7 | kavaratti
# Processing Record 8 of Set 7 | rengasdengklok
# Processing Record 9 of Set 7 | whitehorse
# Processing Record 10 of Set 7 | nouadhibou
# Processing Record 11 of Set 7 | lagoa
# City not found. Skipping...
# Processing Record 12 of Set 7 | isangel
# Processing Record 13 of Set 7 | hudson bay
# Processing Record 14 of Set 7 | sosua
# City not found. Skipping...
# Processing Record 15 of Set 7 | flinders
# Processing Record 16 of Set 7 | providencia
# Processing Record 17 of Set 7 | hanzhong
# Processing Record 18 of Set 7 | eureka
# City not found. Skipping...
# Processing Record 19 of Set 7 | ust-maya
# Processing Record 20 of Set 7 | sabang
# Processing Record 21 of Set 7 | praia
# Processing Record 22 of Set 7 | buriti alegre
# Processing Record 23 of Set 7 | ahipara
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | hobo
# Processing Record 26 of Set 7 | katobu
# Processing Record 27 of Set 7 | hamilton
# City not found. Skipping...
# Processing Record 28 of Set 7 | holland
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | calintaan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | bijar
# Processing Record 33 of Set 7 | puerto del rosario
# Processing Record 34 of Set 7 | san andres
# Processing Record 35 of Set 7 | swellendam
# Processing Record 36 of Set 7 | jackson
# Processing Record 37 of Set 7 | delta del tigre
# Processing Record 38 of Set 7 | sarahan
# Processing Record 39 of Set 7 | stornoway
# Processing Record 40 of Set 7 | avera
# City not found. Skipping...
# Processing Record 41 of Set 7 | saint-gaudens
# Processing Record 42 of Set 7 | puruliya
# Processing Record 43 of Set 7 | celestun
# Processing Record 44 of Set 7 | romny
# City not found. Skipping...
# Processing Record 45 of Set 7 | yulara
# City not found. Skipping...
# Processing Record 46 of Set 7 | vardo
# Processing Record 47 of Set 7 | springbok
# Processing Record 48 of Set 7 | rancho palos verdes
# Processing Record 49 of Set 7 | bermeo
# Processing Record 1 of Set 8 | ulkan
# Processing Record 2 of Set 8 | clyde river
# Processing Record 3 of Set 8 | dawson creek
# Processing Record 4 of Set 8 | leh
# Processing Record 5 of Set 8 | patea
# Processing Record 6 of Set 8 | kamyshla
# Processing Record 7 of Set 8 | faya
# Processing Record 8 of Set 8 | kenai
# Processing Record 9 of Set 8 | padilla
# Processing Record 10 of Set 8 | anamur
# Processing Record 11 of Set 8 | aswan
# Processing Record 12 of Set 8 | paciran
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | jalu
# Processing Record 15 of Set 8 | genhe
# Processing Record 16 of Set 8 | sjenica
# Processing Record 17 of Set 8 | pohrebyshche
# Processing Record 18 of Set 8 | labuhan
# Processing Record 19 of Set 8 | paamiut
# Processing Record 20 of Set 8 | abu jubayhah
# Processing Record 21 of Set 8 | yongan
# Processing Record 22 of Set 8 | mabopane
# Processing Record 23 of Set 8 | port-cartier
# City not found. Skipping...
# Processing Record 24 of Set 8 | dogondoutchi
# Processing Record 25 of Set 8 | progreso
# Processing Record 26 of Set 8 | vila franca do campo
# Processing Record 27 of Set 8 | ponta delgada
# City not found. Skipping...
# Processing Record 28 of Set 8 | poum
# Processing Record 29 of Set 8 | dakar
# Processing Record 30 of Set 8 | gympie
# Processing Record 31 of Set 8 | schwandorf
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | waling
# Processing Record 34 of Set 8 | huarmey
# Processing Record 35 of Set 8 | trelew
# Processing Record 36 of Set 8 | sept-iles
# Processing Record 37 of Set 8 | glens falls
# Processing Record 38 of Set 8 | akdepe
# Processing Record 39 of Set 8 | san cristobal
# Processing Record 40 of Set 8 | klaksvik
# Processing Record 41 of Set 8 | giyani
# Processing Record 42 of Set 8 | mapiripan
# Processing Record 43 of Set 8 | sao miguel do araguaia
# Processing Record 44 of Set 8 | lithakia
# Processing Record 45 of Set 8 | kaduy
# Processing Record 46 of Set 8 | sovetskiy
# Processing Record 47 of Set 8 | lima
# Processing Record 48 of Set 8 | khandbari
# Processing Record 49 of Set 8 | bandundu
# Processing Record 1 of Set 9 | sheregesh
# Processing Record 2 of Set 9 | tombouctou
# Processing Record 3 of Set 9 | chastyye
# Processing Record 4 of Set 9 | roald
# Processing Record 5 of Set 9 | andenes
# Processing Record 6 of Set 9 | berdigestyakh
# Processing Record 7 of Set 9 | atkarsk
# Processing Record 8 of Set 9 | grand river south east
# Processing Record 9 of Set 9 | jiuquan
# Processing Record 10 of Set 9 | fortuna
# Processing Record 11 of Set 9 | gamba
# Processing Record 12 of Set 9 | aktash
# Processing Record 13 of Set 9 | simbahan
# Processing Record 14 of Set 9 | sindor
# Processing Record 15 of Set 9 | hofn
# Processing Record 16 of Set 9 | oshikango
# Processing Record 17 of Set 9 | sobolevo
# Processing Record 18 of Set 9 | baoding
# Processing Record 19 of Set 9 | mareeba
# Processing Record 20 of Set 9 | kidal
# Processing Record 21 of Set 9 | yerbogachen
# Processing Record 22 of Set 9 | noumea
# Processing Record 23 of Set 9 | leninsk
# Processing Record 24 of Set 9 | fare
# Processing Record 25 of Set 9 | tondano
# Processing Record 26 of Set 9 | pandan
# Processing Record 27 of Set 9 | imbituba
# City not found. Skipping...
# Processing Record 28 of Set 9 | otane
# Processing Record 29 of Set 9 | kitaibaraki
# Processing Record 30 of Set 9 | khandyga
# Processing Record 31 of Set 9 | plateros
# Processing Record 32 of Set 9 | kargasok
# Processing Record 33 of Set 9 | lucea
# Processing Record 34 of Set 9 | soyo
# Processing Record 35 of Set 9 | karasjok
# Processing Record 36 of Set 9 | barrie
# Processing Record 37 of Set 9 | palasa
# Processing Record 38 of Set 9 | santiago del estero
# Processing Record 39 of Set 9 | kazanka
# Processing Record 40 of Set 9 | kholuy
# Processing Record 41 of Set 9 | kashmor
# Processing Record 42 of Set 9 | goma
# Processing Record 43 of Set 9 | trairi
# Processing Record 44 of Set 9 | saint-michel-des-saints
# Processing Record 45 of Set 9 | hambantota
# Processing Record 46 of Set 9 | luanda
# Processing Record 47 of Set 9 | plettenberg bay
# Processing Record 48 of Set 9 | yarmouth
# Processing Record 49 of Set 9 | green valley
# Processing Record 1 of Set 10 | tecpan
# Processing Record 2 of Set 10 | khatra
# Processing Record 3 of Set 10 | parrita
# Processing Record 4 of Set 10 | lufilufi
# Processing Record 5 of Set 10 | moussoro
# Processing Record 6 of Set 10 | bonfim
# Processing Record 7 of Set 10 | outjo
# Processing Record 8 of Set 10 | sungaipenuh
# Processing Record 9 of Set 10 | viedma
# Processing Record 10 of Set 10 | sucre
# Processing Record 11 of Set 10 | northam
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 10 | puerto leguizamo
# Processing Record 13 of Set 10 | alofi
# Processing Record 14 of Set 10 | port macquarie
# Processing Record 15 of Set 10 | ureki
# Processing Record 16 of Set 10 | kamenz
# Processing Record 17 of Set 10 | havre-saint-pierre
# Processing Record 18 of Set 10 | gornopravdinsk
# Processing Record 19 of Set 10 | brindisi
# Processing Record 20 of Set 10 | yuncheng
# Processing Record 21 of Set 10 | rybinsk
# Processing Record 22 of Set 10 | abu dhabi
# Processing Record 23 of Set 10 | marion
# Processing Record 24 of Set 10 | atambua
# Processing Record 25 of Set 10 | vagur
# Processing Record 26 of Set 10 | erdenet
# Processing Record 27 of Set 10 | mumford
# Processing Record 28 of Set 10 | teguldet
# Processing Record 29 of Set 10 | bayji
# Processing Record 30 of Set 10 | batagay-alyta
# Processing Record 31 of Set 10 | emba
# Processing Record 32 of Set 10 | tutoia
# Processing Record 33 of Set 10 | aykhal
# Processing Record 34 of Set 10 | san miguel
# Processing Record 35 of Set 10 | veraval
# Processing Record 36 of Set 10 | san jose
# Processing Record 37 of Set 10 | torbay
# Processing Record 38 of Set 10 | erenhot
# Processing Record 39 of Set 10 | tingi
# Processing Record 40 of Set 10 | pavlivka
# Processing Record 41 of Set 10 | sinop
# Processing Record 42 of Set 10 | aksarka
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 10 | poso
# City not found. Skipping...
# Processing Record 44 of Set 10 | west bay
# Processing Record 45 of Set 10 | veseloyarsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | oriximina
# Processing Record 47 of Set 10 | gat
# Processing Record 48 of Set 10 | ust-omchug
# Processing Record 49 of Set 10 | wewak
# City not found. Skipping...
# Processing Record 1 of Set 11 | shingu
# Processing Record 2 of Set 11 | terrace
# Processing Record 3 of Set 11 | shenjiamen
# City not found. Skipping...
# Processing Record 4 of Set 11 | jian
# Processing Record 5 of Set 11 | esna
# Processing Record 6 of Set 11 | karimpur
# Processing Record 7 of Set 11 | codrington
# Processing Record 8 of Set 11 | merauke
# Processing Record 9 of Set 11 | awjilah
# Processing Record 10 of Set 11 | isiolo
# Processing Record 11 of Set 11 | damietta
# Processing Record 12 of Set 11 | samfya
# Processing Record 13 of Set 11 | palmer
# Processing Record 14 of Set 11 | marawi
# Processing Record 15 of Set 11 | abu zabad
# Processing Record 16 of Set 11 | tucuma
# Processing Record 17 of Set 11 | jiancheng
# Processing Record 18 of Set 11 | sao miguel
# Processing Record 19 of Set 11 | bengkulu
# City not found. Skipping...
# Processing Record 20 of Set 11 | hannibal
# Processing Record 21 of Set 11 | sao jose da coroa grande
# Processing Record 22 of Set 11 | beloha
# Processing Record 23 of Set 11 | bagan
# Processing Record 24 of Set 11 | solnechnyy
# Processing Record 25 of Set 11 | vao
# Processing Record 26 of Set 11 | nome
# Processing Record 27 of Set 11 | ixtapa
# Processing Record 28 of Set 11 | cordoba
# Processing Record 29 of Set 11 | tynda
# City not found. Skipping...
# Processing Record 30 of Set 11 | saint-joseph
# Processing Record 31 of Set 11 | sinnamary
# Processing Record 32 of Set 11 | salekhard
# Processing Record 33 of Set 11 | liverpool
# Processing Record 34 of Set 11 | brisenas
# Processing Record 35 of Set 11 | vestmanna
# Processing Record 36 of Set 11 | pafos
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 11 | parati
# Processing Record 38 of Set 11 | ellensburg
# Processing Record 39 of Set 11 | finschhafen
# Processing Record 40 of Set 11 | san rafael
# Processing Record 41 of Set 11 | armidale
# Processing Record 42 of Set 11 | tigil
# Processing Record 43 of Set 11 | sembe
# Processing Record 44 of Set 11 | mexico
# Processing Record 45 of Set 11 | mackay
# Processing Record 46 of Set 11 | qaracala
# Processing Record 47 of Set 11 | shakawe
# Processing Record 48 of Set 11 | flin flon
# Processing Record 49 of Set 11 | aripuana
# Processing Record 1 of Set 12 | puerto carreno
# Processing Record 2 of Set 12 | westport
# City not found. Skipping...
# Processing Record 3 of Set 12 | castlemaine
# Processing Record 4 of Set 12 | karratha
# Processing Record 5 of Set 12 | lincoln
# Processing Record 6 of Set 12 | paraiso
# Processing Record 7 of Set 12 | kagalnitskaya
# Processing Record 8 of Set 12 | victor harbor
# Processing Record 9 of Set 12 | ust-nera
# City not found. Skipping...
# Processing Record 10 of Set 12 | oktyabrskiy
# Processing Record 11 of Set 12 | wajir
# Processing Record 12 of Set 12 | ust-ishim
# City not found. Skipping...
# Processing Record 13 of Set 12 | adeje
# Processing Record 14 of Set 12 | ban tak
# Processing Record 15 of Set 12 | rock sound
# Processing Record 16 of Set 12 | khor
# Processing Record 17 of Set 12 | alice springs
# Processing Record 18 of Set 12 | ambovombe
# Processing Record 19 of Set 12 | singkawang
# City not found. Skipping...
# Processing Record 20 of Set 12 | fort-shevchenko
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dataframe = pd.DataFrame(weather_dict)

# %%
weather_dataframe.to_csv ('cities.csv')

# %%
weather_dataframe.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     rikitea         100      PF  1580239154        79 -23.12 -134.97
# 1     bintulu          75      MY  1580239154        94   3.17  113.03
# 2  nikolskoye          90      RU  1580239155        95  59.70   30.79
# 3  bredasdorp           0      ZA  1580239155        72 -34.53   20.04
# 4        hilo          90      US  1580239155        83  19.73 -155.09
#
#    Max Temp  Wind Speed
# 0    299.26        5.07
# 1    299.15        1.00
# 2    273.15        5.00
# 3    293.15        5.21
# 4    295.37        5.10

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (01/28/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (01/28/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (01/28/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (01/28/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
